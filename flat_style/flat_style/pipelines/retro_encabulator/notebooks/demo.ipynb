# %% [markdown]
# # Flat-layout Retro-Encabulator demo
#
# This notebook runs directly from the monorepo Git folder, without installing a package or modifying `sys.path`. Databricks adds the monorepo root as an import root, so this project uses the source-tree import `flat_style.flat_style...`. Use the same import in a local IDE only when the monorepo root is the workspace/import root.

# %%
from flat_style.flat_style.pipelines.retro_encabulator.instruments import (
    InverseReactiveCurrent,
    RetroEncabulator,
    synchronize_cardinal_gram_meters,
)

current = InverseReactiveCurrent(ohms=42.0)
encabulator = synchronize_cardinal_gram_meters(RetroEncabulator())

print(f'Inverse reactive current: {current.ohms} ohms')
print(encabulator.stabilize_milford_trunions())
