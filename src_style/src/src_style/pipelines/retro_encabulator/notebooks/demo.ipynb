# %% [markdown]
# # Retro Encabulator

# %%
from src_style.pipelines.instruments import unilateral_phase_detractor

# %%
unilateral_phase_detractor.synchronize_cardinal_gram_meter()

# %%
unilateral_phase_detractor.InverseReactiveCurrent()
